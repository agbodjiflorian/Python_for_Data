# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Read the csv files with pandas and do an exploratory analysis

# %%
#df_airport = files with the list of all airports around the world
df_airport = pd.read_csv(r"C:\Users\Florian AGBODJI\Documents\DataProjects\Aviation\all airports in the world.csv", index_col = 0, sep=';', on_bad_lines='skip')
df_airport
# Out:
#                           name iata  icao        lat         lon      country  \
# 0             A Coruna Airport  LCG  LECO  43.302059   -8.377250        Spain
# 1     Aachen Merzbruck Airport  AAH  EDKA  50.823051    6.186111      Germany
# 2              Aalborg Airport  AAL  EKYT  57.092781    9.849164      Denmark
# 3               Aarhus Airport  AAR  EKAH  56.300011   10.619000      Denmark
# 4           Aarhus Sea Airport  QEA  EKAC  56.151993   10.247725      Denmark
# ...                        ...  ...   ...        ...         ...          ...
# 5090     Zunyi Xinzhou Airport  ZYI  ZUZY  27.811167  107.245972        China
# 5091            Zurich Airport  ZRH  LSZH  47.464722    8.549167  Switzerland
# 5092             Zwara Airport  WAX  HLZW  32.933334   12.083333        Libya
# 5093       Zweibrucken Airport  ZQW  EDRZ  49.209518    7.400647      Germany
# 5094          Zyryanka Airport  ZKP  UESU  65.738335  150.707779       Russia
#
#        alt
# 0      326
# ...

# %%
df_airport
# Out:
#                           name iata  icao        lat         lon      country  \
# 0             A Coruna Airport  LCG  LECO  43.302059   -8.377250        Spain
# 1     Aachen Merzbruck Airport  AAH  EDKA  50.823051    6.186111      Germany
# 2              Aalborg Airport  AAL  EKYT  57.092781    9.849164      Denmark
# 3               Aarhus Airport  AAR  EKAH  56.300011   10.619000      Denmark
# 4           Aarhus Sea Airport  QEA  EKAC  56.151993   10.247725      Denmark
# ...                        ...  ...   ...        ...         ...          ...
# 5090     Zunyi Xinzhou Airport  ZYI  ZUZY  27.811167  107.245972        China
# 5091            Zurich Airport  ZRH  LSZH  47.464722    8.549167  Switzerland
# 5092             Zwara Airport  WAX  HLZW  32.933334   12.083333        Libya
# 5093       Zweibrucken Airport  ZQW  EDRZ  49.209518    7.400647      Germany
# 5094          Zyryanka Airport  ZKP  UESU  65.738335  150.707779       Russia
#
#        alt
# 0      326
# ...

# %%
df_airport.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4664 entries, 0 to 5094
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     4664 non-null   object
#  1   iata     4664 non-null   object
#  2   icao     4664 non-null   object
#  3   lat      4664 non-null   float64
#  4   lon      4664 non-null   float64
#  5   country  4664 non-null   object
#  6   alt      4664 non-null   int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 291.5+ KB

# %%
df_airport.shape
# Out:
# (4664, 7)

# %%
df_airport.describe()
# Out:
#                lat          lon           alt
# count  4664.000000  4664.000000   4664.000000
# mean     27.558738    -2.736980   1037.237779
# std      26.985667    89.300191   1714.832931
# min     -79.777687  -179.876007   -128.000000
# 25%      11.884860   -82.896126     65.750000
# 50%      35.217730     3.477596    346.500000
# 75%      46.166919    73.241516   1161.000000
# max      83.699997   179.339798  14418.000000

# %%
df_airport.nunique()
# Out:
# name       4651
# iata       4664
# icao       4662
# lat        4652
# lon        4657
# country     225
# alt        1947
# dtype: int64

# %%
df_airport.isnull().sum()
# Out:
# name       0
# iata       0
# icao       0
# lat        0
# lon        0
# country    0
# alt        0
# dtype: int64

# %%
df_airport.dtypes
# Out:
# name        object
# iata        object
# icao        object
# lat        float64
# lon        float64
# country     object
# alt          int64
# dtype: object

# %%
df_airport.drop_duplicates()
# Out:
#                           name iata  icao        lat         lon      country  \
# 0             A Coruna Airport  LCG  LECO  43.302059   -8.377250        Spain
# 1     Aachen Merzbruck Airport  AAH  EDKA  50.823051    6.186111      Germany
# 2              Aalborg Airport  AAL  EKYT  57.092781    9.849164      Denmark
# 3               Aarhus Airport  AAR  EKAH  56.300011   10.619000      Denmark
# 4           Aarhus Sea Airport  QEA  EKAC  56.151993   10.247725      Denmark
# ...                        ...  ...   ...        ...         ...          ...
# 5090     Zunyi Xinzhou Airport  ZYI  ZUZY  27.811167  107.245972        China
# 5091            Zurich Airport  ZRH  LSZH  47.464722    8.549167  Switzerland
# 5092             Zwara Airport  WAX  HLZW  32.933334   12.083333        Libya
# 5093       Zweibrucken Airport  ZQW  EDRZ  49.209518    7.400647      Germany
# 5094          Zyryanka Airport  ZKP  UESU  65.738335  150.707779       Russia
#
#        alt
# 0      326
# ...

# %%
df_airport.shape
# Out:
# (4664, 7)

# %%
#df_accident = data showing all the accident in the aviation sector from 1919 to 2023
df_accident = pd.read_csv(r"C:\Users\Florian AGBODJI\Documents\DataProjects\Aviation\aviation-accident-data-1919-2023.csv")
df_accident
# Out:
#               date                       type registration  \
# 0        date unk.             Antonov An-12B       T-1206
# 1        date unk.             Antonov An-12B       T-1204
# 2        date unk.             Antonov An-12B       T-1201
# 3        date unk.            Antonov An-12BK          NaN
# 4        date unk.            Antonov An-12BP   CCCP-11815
# ...            ...                        ...          ...
# 23962  11-MAY-2023               Hawker 900XP       PK-LRU
# 23963  11-MAY-2023  Cessna 208B Grand Caravan       PK-NGA
# 23964  12-MAY-2023  Cessna 208B Grand Caravan       5X-RBR
# 23965  14-MAY-2023            Boeing 747-4R7F       LX-OCV
# 23966  15-MAY-2023                Learjet 35A       D-CGFQ
#
#                      operator fatalities             location  \
# 0               Indonesian AF        NaN                  NaN
# 1               Indonesian AF        NaN                  NaN
# 2               Indonesian AF        NaN                  NaN
# ...

# %%
df_accident.isnull().sum()
# Out:
# date               0
# type               0
# registration    1548
# operator           4
# fatalities      3938
# location         948
# country            0
# cat                0
# year               0
# dtype: int64

# %%
df_accident.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23967 entries, 0 to 23966
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          23967 non-null  object
#  1   type          23967 non-null  object
#  2   registration  22419 non-null  object
#  3   operator      23963 non-null  object
#  4   fatalities    20029 non-null  object
#  5   location      23019 non-null  object
#  6   country       23967 non-null  object
#  7   cat           23967 non-null  object
#  8   year          23967 non-null  object
# dtypes: object(9)
# memory usage: 1.6+ MB

# %% [markdown]
# # Clean the data

# %%
# remove all the rows where the date is unknown
df_accident = df_accident[df_accident['date'] != 'date unk.']
df_accident
# Out:
#               date                       type registration  \
# 61     02-AUG-1919              Caproni Ca.48          NaN
# 62     11-AUG-1919            Felixstowe Fury         N123
# 63     23-FEB-1920           Handley Page O/7       G-EANV
# 64     25-FEB-1920         Handley Page O/400       G-EAMC
# 65     30-JUN-1920         Handley Page O/400       G-EAKE
# ...            ...                        ...          ...
# 23962  11-MAY-2023               Hawker 900XP       PK-LRU
# 23963  11-MAY-2023  Cessna 208B Grand Caravan       PK-NGA
# 23964  12-MAY-2023  Cessna 208B Grand Caravan       5X-RBR
# 23965  14-MAY-2023            Boeing 747-4R7F       LX-OCV
# 23966  15-MAY-2023                Learjet 35A       D-CGFQ
#
#                      operator fatalities             location       country  \
# 61                    Caproni         14               Verona         Italy
# 62                        RAF          1  near Felixtowe RNAS          U.K.
# ...

# %%
df_accident_clean = df_accident

# %%
# check the date format properly
df_accident_clean['date'] = df_accident_clean['date'].str.strip()
df_accident_clean
# Out:
# C:\Users\Florian AGBODJI\AppData\Local\Temp\ipykernel_10692\4258122453.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_accident_clean['date'] = df_accident_clean['date'].str.strip()
#               date                       type registration  \
# 61     02-AUG-1919              Caproni Ca.48          NaN
# 62     11-AUG-1919            Felixstowe Fury         N123
# 63     23-FEB-1920           Handley Page O/7       G-EANV
# 64     25-FEB-1920         Handley Page O/400       G-EAMC
# 65     30-JUN-1920         Handley Page O/400       G-EAKE
# ...            ...                        ...          ...
# 23962  11-MAY-2023               Hawker 900XP       PK-LRU
# 23963  11-MAY-2023  Cessna 208B Grand Caravan       PK-NGA
# ...

# %%
df_accident_clean
# Out:
#               date                       type registration  \
# 61     02-AUG-1919              Caproni Ca.48          NaN
# 62     11-AUG-1919            Felixstowe Fury         N123
# 63     23-FEB-1920           Handley Page O/7       G-EANV
# 64     25-FEB-1920         Handley Page O/400       G-EAMC
# 65     30-JUN-1920         Handley Page O/400       G-EAKE
# ...            ...                        ...          ...
# 23962  11-MAY-2023               Hawker 900XP       PK-LRU
# 23963  11-MAY-2023  Cessna 208B Grand Caravan       PK-NGA
# 23964  12-MAY-2023  Cessna 208B Grand Caravan       5X-RBR
# 23965  14-MAY-2023            Boeing 747-4R7F       LX-OCV
# 23966  15-MAY-2023                Learjet 35A       D-CGFQ
#
#                      operator fatalities             location       country  \
# 61                    Caproni         14               Verona         Italy
# 62                        RAF          1  near Felixtowe RNAS          U.K.
# ...

# %%
df_accident_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23906 entries, 61 to 23966
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          23906 non-null  object
#  1   type          23906 non-null  object
#  2   registration  22361 non-null  object
#  3   operator      23902 non-null  object
#  4   fatalities    20004 non-null  object
#  5   location      22986 non-null  object
#  6   country       23906 non-null  object
#  7   cat           23906 non-null  object
#  8   year          23906 non-null  object
# dtypes: object(9)
# memory usage: 1.8+ MB

# %%
df_accident_new = df_accident_clean

# %%
df_accident_new
# Out:
#               date                       type registration  \
# 61     02-AUG-1919              Caproni Ca.48          NaN
# 62     11-AUG-1919            Felixstowe Fury         N123
# 63     23-FEB-1920           Handley Page O/7       G-EANV
# 64     25-FEB-1920         Handley Page O/400       G-EAMC
# 65     30-JUN-1920         Handley Page O/400       G-EAKE
# ...            ...                        ...          ...
# 23962  11-MAY-2023               Hawker 900XP       PK-LRU
# 23963  11-MAY-2023  Cessna 208B Grand Caravan       PK-NGA
# 23964  12-MAY-2023  Cessna 208B Grand Caravan       5X-RBR
# 23965  14-MAY-2023            Boeing 747-4R7F       LX-OCV
# 23966  15-MAY-2023                Learjet 35A       D-CGFQ
#
#                      operator fatalities             location       country  \
# 61                    Caproni         14               Verona         Italy
# 62                        RAF          1  near Felixtowe RNAS          U.K.
# ...

# %%
# split the date column in three other columns to clean the data column based on the errors in each new columns(day, month, year)

df_accident_new[['Day', 'Month', 'Yearr']] = df_accident_new.date.str.split("-", expand = True)

df_accident_new
# Out:
# C:\Users\Florian AGBODJI\AppData\Local\Temp\ipykernel_10692\3301551471.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_accident_new[['Day', 'Month', 'Yearr']] = df_accident_new.date.str.split("-", expand = True)
#               date                       type registration  \
# 61     02-AUG-1919              Caproni Ca.48          NaN
# 62     11-AUG-1919            Felixstowe Fury         N123
# 63     23-FEB-1920           Handley Page O/7       G-EANV
# 64     25-FEB-1920         Handley Page O/400       G-EAMC
# 65     30-JUN-1920         Handley Page O/400       G-EAKE
# ...            ...                        ...          ...
# 23962  11-MAY-2023               Hawker 900XP       PK-LRU
# ...

# %%
df_accident_new.nunique()
# Out:
# date            15078
# type             3197
# registration    21907
# operator         6005
# fatalities        369
# location        14588
# country           232
# cat                11
# year              105
# Day                32
# Month              14
# Yearr             105
# dtype: int64

# %%
# add a boolean value True to all day columns containing a digit
df_accident_new['Day Number'] = df_accident_new['Day'].str.isdigit()
# Out:
# C:\Users\Florian AGBODJI\AppData\Local\Temp\ipykernel_10692\172838713.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_accident_new['Day Number'] = df_accident_new['Day'].str.isdigit()

# %%
df_accident_new
# Out:
#               date                       type registration  \
# 61     02-AUG-1919              Caproni Ca.48          NaN
# 62     11-AUG-1919            Felixstowe Fury         N123
# 63     23-FEB-1920           Handley Page O/7       G-EANV
# 64     25-FEB-1920         Handley Page O/400       G-EAMC
# 65     30-JUN-1920         Handley Page O/400       G-EAKE
# ...            ...                        ...          ...
# 23962  11-MAY-2023               Hawker 900XP       PK-LRU
# 23963  11-MAY-2023  Cessna 208B Grand Caravan       PK-NGA
# 23964  12-MAY-2023  Cessna 208B Grand Caravan       5X-RBR
# 23965  14-MAY-2023            Boeing 747-4R7F       LX-OCV
# 23966  15-MAY-2023                Learjet 35A       D-CGFQ
#
#                      operator fatalities             location       country  \
# 61                    Caproni         14               Verona         Italy
# 62                        RAF          1  near Felixtowe RNAS          U.K.
# ...

# %%
df_accident_new.group_by(['Day Number']).count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 df_accident_new.group_by(['Day Number']).count()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'group_by'

# %%
# select all the rows where the Day isn't a digit
df_accident_new[~df_accident_new['Day Number']]
# Out:
#               date                    type registration  \
# 84     ??-???-1923           Aeromarine 75          NaN
# 109    ??-DEC-1928          Junkers G.31ce       D-1137
# 111    ??-FEB-1929            Junkers G.24        D-899
# 128    ??-OCT-1929  Farman F.63bis Goliath       F-FARI
# 165    ??-???-1930   Junkers JuG-1W (G.24)          NaN
# ...            ...                     ...          ...
# 22642  ??-OCT-2016   Cessna 500 Citation I       N888JL
# 22681  ??-???-2016   Cessna 500 Citation I       N628BS
# 23111  ??-???-2018  Rockwell Sabreliner 80       N337KL
# 23573  ??-JAN-2021            Antonov An-2          NaN
# 23831  ??-JUN-2022           Antonov An-2R     RA-17951
#
#                       operator fatalities                location  \
# 84          Aeromarine Airways          0          Havana harbour
# 109         Deutsche Lufthansa        NaN                     NaN
# 111         Deutsche Lufthansa        NaN       Epinais, Bretagne
# ...

# %%
# replace all the NaN values with an empty string
df_accident_new = df_accident_new.fillna('')
df_accident_new
# Out:
#               date                       type registration  \
# 61     02-AUG-1919              Caproni Ca.48
# 62     11-AUG-1919            Felixstowe Fury         N123
# 63     23-FEB-1920           Handley Page O/7       G-EANV
# 64     25-FEB-1920         Handley Page O/400       G-EAMC
# 65     30-JUN-1920         Handley Page O/400       G-EAKE
# ...            ...                        ...          ...
# 23962  11-MAY-2023               Hawker 900XP       PK-LRU
# 23963  11-MAY-2023  Cessna 208B Grand Caravan       PK-NGA
# 23964  12-MAY-2023  Cessna 208B Grand Caravan       5X-RBR
# 23965  14-MAY-2023            Boeing 747-4R7F       LX-OCV
# 23966  15-MAY-2023                Learjet 35A       D-CGFQ
#
#                      operator fatalities             location       country  \
# 61                    Caproni         14               Verona         Italy
# 62                        RAF          1  near Felixtowe RNAS          U.K.
# ...

# %%
df_accident_new[~df_accident_new['Day Number']]
# Out:
#               date                    type registration  \
# 84     ??-???-1923           Aeromarine 75
# 109    ??-DEC-1928          Junkers G.31ce       D-1137
# 111    ??-FEB-1929            Junkers G.24        D-899
# 128    ??-OCT-1929  Farman F.63bis Goliath       F-FARI
# 165    ??-???-1930   Junkers JuG-1W (G.24)
# ...            ...                     ...          ...
# 22642  ??-OCT-2016   Cessna 500 Citation I       N888JL
# 22681  ??-???-2016   Cessna 500 Citation I       N628BS
# 23111  ??-???-2018  Rockwell Sabreliner 80       N337KL
# 23573  ??-JAN-2021            Antonov An-2
# 23831  ??-JUN-2022           Antonov An-2R     RA-17951
#
#                       operator fatalities                location  \
# 84          Aeromarine Airways          0          Havana harbour
# 109         Deutsche Lufthansa
# 111         Deutsche Lufthansa                  Epinais, Bretagne
# 128                       SGTA
# 165                  Soviet AF
# ...

# %%
# replace the empty values with 0
df_accident_new['fatalities'] = df_accident_new['fatalities'].replace('', 0)
df_accident_new
# Out:
#               date                       type registration  \
# 61     02-AUG-1919              Caproni Ca.48
# 62     11-AUG-1919            Felixstowe Fury         N123
# 63     23-FEB-1920           Handley Page O/7       G-EANV
# 64     25-FEB-1920         Handley Page O/400       G-EAMC
# 65     30-JUN-1920         Handley Page O/400       G-EAKE
# ...            ...                        ...          ...
# 23962  11-MAY-2023               Hawker 900XP       PK-LRU
# 23963  11-MAY-2023  Cessna 208B Grand Caravan       PK-NGA
# 23964  12-MAY-2023  Cessna 208B Grand Caravan       5X-RBR
# 23965  14-MAY-2023            Boeing 747-4R7F       LX-OCV
# 23966  15-MAY-2023                Learjet 35A       D-CGFQ
#
#                      operator fatalities             location       country  \
# 61                    Caproni         14               Verona         Italy
# 62                        RAF          1  near Felixtowe RNAS          U.K.
# ...

# %%
# replace the empty values with unknown
df_accident_new['location'] = df_accident_new['location'].replace('', 'unknown')
df_accident_new
# Out:
#               date                       type registration  \
# 61     02-AUG-1919              Caproni Ca.48
# 62     11-AUG-1919            Felixstowe Fury         N123
# 63     23-FEB-1920           Handley Page O/7       G-EANV
# 64     25-FEB-1920         Handley Page O/400       G-EAMC
# 65     30-JUN-1920         Handley Page O/400       G-EAKE
# ...            ...                        ...          ...
# 23962  11-MAY-2023               Hawker 900XP       PK-LRU
# 23963  11-MAY-2023  Cessna 208B Grand Caravan       PK-NGA
# 23964  12-MAY-2023  Cessna 208B Grand Caravan       5X-RBR
# 23965  14-MAY-2023            Boeing 747-4R7F       LX-OCV
# 23966  15-MAY-2023                Learjet 35A       D-CGFQ
#
#                      operator fatalities             location       country  \
# 61                    Caproni         14               Verona         Italy
# 62                        RAF          1  near Felixtowe RNAS          U.K.
# ...

# %%
df_accident_new[~df_accident_new['Day Number']]
# Out:
#               date                    type registration  \
# 84     ??-???-1923           Aeromarine 75
# 109    ??-DEC-1928          Junkers G.31ce       D-1137
# 111    ??-FEB-1929            Junkers G.24        D-899
# 128    ??-OCT-1929  Farman F.63bis Goliath       F-FARI
# 165    ??-???-1930   Junkers JuG-1W (G.24)
# ...            ...                     ...          ...
# 22642  ??-OCT-2016   Cessna 500 Citation I       N888JL
# 22681  ??-???-2016   Cessna 500 Citation I       N628BS
# 23111  ??-???-2018  Rockwell Sabreliner 80       N337KL
# 23573  ??-JAN-2021            Antonov An-2
# 23831  ??-JUN-2022           Antonov An-2R     RA-17951
#
#                       operator fatalities                location  \
# 84          Aeromarine Airways          0          Havana harbour
# 109         Deutsche Lufthansa          0                 unknown
# 111         Deutsche Lufthansa          0       Epinais, Bretagne
# ...

# %%
# drop all the rows with an empty Month
df_accident_new = df_accident_new.drop(df_accident_new[df_accident_new['Month'] == "???"].index)

# %%
# after dropping all the rows with an empty month, I created a new date column by giving a specific value (1st of the month, 01) to the rows with an empty day

df_accident_new['new_date'] = df_accident_new['Day'] + '-' + df_accident_new['Month'] + '-' + df_accident_new['Yearr']
df_accident_new
# Out:
#               date                       type registration  \
# 61     02-AUG-1919              Caproni Ca.48
# 62     11-AUG-1919            Felixstowe Fury         N123
# 63     23-FEB-1920           Handley Page O/7       G-EANV
# 64     25-FEB-1920         Handley Page O/400       G-EAMC
# 65     30-JUN-1920         Handley Page O/400       G-EAKE
# ...            ...                        ...          ...
# 23962  11-MAY-2023               Hawker 900XP       PK-LRU
# 23963  11-MAY-2023  Cessna 208B Grand Caravan       PK-NGA
# 23964  12-MAY-2023  Cessna 208B Grand Caravan       5X-RBR
# 23965  14-MAY-2023            Boeing 747-4R7F       LX-OCV
# 23966  15-MAY-2023                Learjet 35A       D-CGFQ
#
#                      operator fatalities             location       country  \
# 61                    Caproni         14               Verona         Italy
# 62                        RAF          1  near Felixtowe RNAS          U.K.
# ...

# %%
from datetime import datetime

# %%
# change the months notation from capital letters to numbers 
months = {"JAN" : "01",
          "FEB" : "02",
          "MAR" : "03",
          "APR" : "04",
          "MAY" : "05",
          "JUN" : "06",
          "JUL" : "07",
          "AUG" : "08",
          "SEP" : "09",
          "OCT" : "10",
          "NOV" : "11",
          "DEC" : "12"
         }

for key, value in months.items():
    df_accident_new['Month'] = df_accident_new['Month'].replace(key, value)

# %%
df_accident_new['new_date'] = df_accident_new['Day'] + '-' + df_accident_new['Month'] + '-' + df_accident_new['Yearr']
df_accident_new
# Out:
#               date                       type registration  \
# 61     02-AUG-1919              Caproni Ca.48
# 62     11-AUG-1919            Felixstowe Fury         N123
# 63     23-FEB-1920           Handley Page O/7       G-EANV
# 64     25-FEB-1920         Handley Page O/400       G-EAMC
# 65     30-JUN-1920         Handley Page O/400       G-EAKE
# ...            ...                        ...          ...
# 23962  11-MAY-2023               Hawker 900XP       PK-LRU
# 23963  11-MAY-2023  Cessna 208B Grand Caravan       PK-NGA
# 23964  12-MAY-2023  Cessna 208B Grand Caravan       5X-RBR
# 23965  14-MAY-2023            Boeing 747-4R7F       LX-OCV
# 23966  15-MAY-2023                Learjet 35A       D-CGFQ
#
#                      operator fatalities             location       country  \
# 61                    Caproni         14               Verona         Italy
# 62                        RAF          1  near Felixtowe RNAS          U.K.
# ...

# %%
df_accident_new['new_date'] = df_accident_new['new_date'].str.replace('-', '/')
df_accident_new
# Out:
#               date                       type registration  \
# 61     02-AUG-1919              Caproni Ca.48
# 62     11-AUG-1919            Felixstowe Fury         N123
# 63     23-FEB-1920           Handley Page O/7       G-EANV
# 64     25-FEB-1920         Handley Page O/400       G-EAMC
# 65     30-JUN-1920         Handley Page O/400       G-EAKE
# ...            ...                        ...          ...
# 23962  11-MAY-2023               Hawker 900XP       PK-LRU
# 23963  11-MAY-2023  Cessna 208B Grand Caravan       PK-NGA
# 23964  12-MAY-2023  Cessna 208B Grand Caravan       5X-RBR
# 23965  14-MAY-2023            Boeing 747-4R7F       LX-OCV
# 23966  15-MAY-2023                Learjet 35A       D-CGFQ
#
#                      operator fatalities             location       country  \
# 61                    Caproni         14               Verona         Italy
# 62                        RAF          1  near Felixtowe RNAS          U.K.
# ...

# %%
# change the date format from str to datetime

def subtract_3_days(match):
    days = int(match.group(1))
    return str(days - 3)

tempdate = pd.to_datetime(df_accident_new["new_date"], format="%d/%m/%Y", errors="coerce")
fixed_dates = df_accident_new.loc[tempdate.isna(), "new_date"].str.replace(r"(?<=/)(\d+)(?=/)", subtract_3_days)
tempdate.update(pd.to_datetime(fixed_dates, format="%d/%m/%Y"))

df_accident_new["clean_date"] = tempdate
df_accident_new
# Out:
# C:\Users\Florian AGBODJI\AppData\Local\Temp\ipykernel_10692\11752252.py:8: FutureWarning: The default value of regex will change from True to False in a future version.
#   fixed_dates = df_accident_new.loc[tempdate.isna(), "new_date"].str.replace(r"(?<=/)(\d+)(?=/)", subtract_3_days)
#               date                       type registration  \
# 61     02-AUG-1919              Caproni Ca.48
# 62     11-AUG-1919            Felixstowe Fury         N123
# 63     23-FEB-1920           Handley Page O/7       G-EANV
# 64     25-FEB-1920         Handley Page O/400       G-EAMC
# 65     30-JUN-1920         Handley Page O/400       G-EAKE
# ...            ...                        ...          ...
# 23962  11-MAY-2023               Hawker 900XP       PK-LRU
# 23963  11-MAY-2023  Cessna 208B Grand Caravan       PK-NGA
# 23964  12-MAY-2023  Cessna 208B Grand Caravan       5X-RBR
# 23965  14-MAY-2023            Boeing 747-4R7F       LX-OCV
# ...

# %%
df_accident_new.dtypes
# Out:
# date                    object
# type                    object
# registration            object
# operator                object
# fatalities              object
# location                object
# country                 object
# cat                     object
# year                    object
# Day                     object
# Month                   object
# Yearr                   object
# Day Number                bool
# nMonth                  object
# new_date                object
# clean_date      datetime64[ns]
# dtype: object

# %%
# get the week days from 0 (monday) to 6 (sunday)
df_accident_new['day_of_week'] = df_accident_new['clean_date'].dt.dayofweek
df_accident_new
# Out:
#               date                       type registration  \
# 61     02-AUG-1919              Caproni Ca.48
# 62     11-AUG-1919            Felixstowe Fury         N123
# 63     23-FEB-1920           Handley Page O/7       G-EANV
# 64     25-FEB-1920         Handley Page O/400       G-EAMC
# 65     30-JUN-1920         Handley Page O/400       G-EAKE
# ...            ...                        ...          ...
# 23962  11-MAY-2023               Hawker 900XP       PK-LRU
# 23963  11-MAY-2023  Cessna 208B Grand Caravan       PK-NGA
# 23964  12-MAY-2023  Cessna 208B Grand Caravan       5X-RBR
# 23965  14-MAY-2023            Boeing 747-4R7F       LX-OCV
# 23966  15-MAY-2023                Learjet 35A       D-CGFQ
#
#                      operator fatalities             location       country  \
# 61                    Caproni         14               Verona         Italy
# 62                        RAF          1  near Felixtowe RNAS          U.K.
# ...

# %%
# add a column with the week day names
days = {
    0: 'Monday',
    1: 'Tuesday',
    2: 'Wednesday',
    3: 'Thursday',
    4: 'Friday',
    5: 'Saturday',
    6: 'Sunday'
}

df_accident_new['day_of_week'] = df_accident_new['day_of_week'].map(days)

df_accident_new
# Out:
#               date                       type registration  \
# 61     02-AUG-1919              Caproni Ca.48
# 62     11-AUG-1919            Felixstowe Fury         N123
# 63     23-FEB-1920           Handley Page O/7       G-EANV
# 64     25-FEB-1920         Handley Page O/400       G-EAMC
# 65     30-JUN-1920         Handley Page O/400       G-EAKE
# ...            ...                        ...          ...
# 23962  11-MAY-2023               Hawker 900XP       PK-LRU
# 23963  11-MAY-2023  Cessna 208B Grand Caravan       PK-NGA
# 23964  12-MAY-2023  Cessna 208B Grand Caravan       5X-RBR
# 23965  14-MAY-2023            Boeing 747-4R7F       LX-OCV
# 23966  15-MAY-2023                Learjet 35A       D-CGFQ
#
#                      operator fatalities             location       country  \
# 61                    Caproni         14               Verona         Italy
# 62                        RAF          1  near Felixtowe RNAS          U.K.
# ...

# %%
# delete the old date column
df_accident_new = df_accident_new.drop(columns = ['date', 'Day Number', 'Yearr', 'new_date'])

# %%
df_accident_new.dtypes
# Out:
# type                    object
# registration            object
# operator                object
# fatalities              object
# location                object
# country                 object
# cat                     object
# year                    object
# Day                     object
# Month                   object
# nMonth                  object
# clean_date      datetime64[ns]
# day_of_week             object
# dtype: object

# %%
df_accident_new = df_accident_new.rename(columns={'clean_date': 'date', 'Month': 'month', 'Day':'day', 'nMonth':'month_name'}) 
df_accident_new
# Out:
#                             type registration                operator  \
# 61                 Caproni Ca.48                              Caproni
# 62               Felixstowe Fury         N123                     RAF
# 63              Handley Page O/7       G-EANV  Handley Page Transport
# 64            Handley Page O/400       G-EAMC  Handley Page Transport
# 65            Handley Page O/400       G-EAKE  Handley Page Transport
# ...                          ...          ...                     ...
# 23962               Hawker 900XP       PK-LRU  Angkasa Super Services
# 23963  Cessna 208B Grand Caravan       PK-NGA  Nasional Global Aviasi
# 23964  Cessna 208B Grand Caravan       5X-RBR            Bar Aviation
# 23965            Boeing 747-4R7F       LX-OCV                Cargolux
# 23966                Learjet 35A       D-CGFQ                     GFD
#
#       fatalities             location       country cat  year day month  \
# ...

# %%
# set the date column as index

df_accident_new.set_index('date', inplace=True)

# %%
df_accident_new
# Out:
#                                  type registration                operator  \
# date
# 1919-08-02              Caproni Ca.48                              Caproni
# 1919-08-11            Felixstowe Fury         N123                     RAF
# 1920-02-23           Handley Page O/7       G-EANV  Handley Page Transport
# 1920-02-25         Handley Page O/400       G-EAMC  Handley Page Transport
# 1920-06-30         Handley Page O/400       G-EAKE  Handley Page Transport
# ...                               ...          ...                     ...
# 2023-05-11               Hawker 900XP       PK-LRU  Angkasa Super Services
# 2023-05-11  Cessna 208B Grand Caravan       PK-NGA  Nasional Global Aviasi
# 2023-05-12  Cessna 208B Grand Caravan       5X-RBR            Bar Aviation
# 2023-05-14            Boeing 747-4R7F       LX-OCV                Cargolux
# 2023-05-15                Learjet 35A       D-CGFQ                     GFD
#
# ...

# %% [markdown]
# # Analysis

# %% [markdown]
# # 1- Total number of airplane accident ?

# %%
df_accident_new['type'].count()
# Out:
# 23663

# %% [markdown]
# # 2- Number of companies affected ?

# %%
df_accident_new['operator'].nunique()
# Out:
# 5969

# %% [markdown]
# # - Companies with the lowest number of incidents ?

# %%
nb_accident_company = df_accident_new['operator'].value_counts().sort_values(ascending=True)
#nb_accident_company.filter(like = 'Ethio', axis = 0)
nb_accident_company
# Out:
# Extrapoint LLC       1
# Dassault             1
# Air Melanesie        1
# Mar Pon              1
# Nepalese AF          1
#                   ...
# German AF          478
# US Navy            744
# RAF                918
# USAF              1120
# USAAF             2597
# Name: operator, Length: 5969, dtype: int64

# %% [markdown]
# # 3- Companies with the highest number of incidents ?

# %%
nb_accident_company = df_accident_new['operator'].value_counts().sort_values(ascending=False)
nb_accident_company
# Out:
# USAAF                         2597
# USAF                          1120
# RAF                            918
# US Navy                        744
# German AF                      478
#                               ...
# FAI Air Service, op.for UN       1
# Turbine Services                 1
# AÃ©roclub Paris-Est              1
# OzAir Charter Service            1
# Bar Aviation                     1
# Name: operator, Length: 5969, dtype: int64

# %% [markdown]
# # 4- Year, month with the highest number of incidents?

# %%
nb_year = df_accident_new['year'].value_counts().sort_values(ascending=False)
nb_year
# Out:
# 1944    1494
# 1945    1440
# 1943     759
# 1969     387
# 1946     376
#         ...
# 1924       3
# 1922       3
# 1925       2
# 1927       2
# 1919       2
# Name: year, Length: 105, dtype: int64

# %%
nb_month = df_accident_new['month_name'].value_counts().sort_values(ascending=False)
nb_month
# Out:
# JAN    2100
# DEC    2094
# MAR    2091
# SEP    2091
# MAY    2044
# JUL    1987
# AUG    1929
# JUN    1915
# NOV    1905
# APR    1894
# OCT    1841
# FEB    1768
# Name: month_name, dtype: int64

# %% [markdown]
# # 5- Weekday with the highest number of incidents ?

# %%
nb_day = df_accident_new['day_of_week'].value_counts().sort_values(ascending=False)
nb_day
# Out:
# Friday       3744
# Thursday     3538
# Wednesday    3518
# Tuesday      3486
# Monday       3358
# Saturday     3226
# Sunday       2789
# Name: day_of_week, dtype: int64

# %% [markdown]
# # 6- Date with the highest number of incidents ?

# %%
nb_date = df_accident_new['day'].value_counts().sort_values(ascending=False)
nb_date
# Out:
# 01    954
# 10    923
# 15    825
# 24    824
# 27    805
# 19    801
# 23    798
# 13    790
# 06    783
# 17    781
# 09    779
# 18    775
# 11    773
# 12    771
# 22    768
# 04    767
# 07    765
# 28    764
# 21    761
# 16    756
# 14    755
# 26    746
# 25    743
# 02    741
# 08    728
# 30    723
# 05    722
# 03    722
# 20    704
# 29    693
# 31    419
# Name: day, dtype: int64

# %% [markdown]
# # 7- Type of plane with the highest number of incidents ?

# %%
nb_type = df_accident_new['type'].value_counts().sort_values(ascending=False)
nb_type
# Out:
# Douglas C-47A (DC-3)    1902
# Douglas C-47 (DC-3)      666
# Douglas C-47B (DC-3)     588
# Curtiss C-46A            563
# Junkers Ju-52/3m         455
#                         ...
# Yunshuji Y-12-II           1
# Antonov An-74TK-100        1
# Boeing 747-128 (SF)        1
# NAMC YS-11A-214            1
# Boeing 777-233LR           1
# Name: type, Length: 3183, dtype: int64

# %% [markdown]
# # 8- Country with the highest number of incidents ?

# %%
nb_location = df_accident_new['country'].value_counts().sort_values(ascending=False)
nb_location
# Out:
# USA                4367
# Russia             1384
# U.K.                835
# Canada              822
# Unknown country     756
#                    ...
# Tuvalu                1
# Cook Isl.             1
# Tonga                 1
# Mauritius             1
# Macau                 1
# Name: country, Length: 232, dtype: int64

# %% [markdown]
# # 9- Location with the highest number of incidents ?

# %%
place = df_accident_new.groupby('country')['location'].value_counts().sort_values(ascending=False)
place
# Out:
# country          location
# Unknown country  unknown                     676
# Cuba             Havana-JosÃ© Mar...         106
# USA              Miami Internatio...          71
# Lebanon          Beirut Internati...          48
# Russia           unknown                      45
#                                             ...
# Mexico           Las Lomitas                   1
#                  Las Mesas                     1
#                  Leon Airport (BJX)            1
#                  LeÃ³n                         1
# Zimbabwe         near Salisbury Airpor...      1
# Name: location, Length: 14732, dtype: int64

# %% [markdown]
# # 10- Highest number of casualties and Where ?

# %%
#df_accident_new['fatalities'] = df_accident_new['fatalities'].astype(int)
df_accident_new.loc['1977-03-27']
#df_accident_new.dtypes
# Out:
#                        type registration operator fatalities  \
# date
# 1977-03-27   Boeing 747-121       N736PA   Pan Am        335
# 1977-03-27  Boeing 747-206B       PH-BUF      KLM        248
#
#                        location country cat  year day month month_name  \
# date
# 1977-03-27  Tenerife-Los Rod...   Spain  A1  1977  27    03        MAR
# 1977-03-27  Tenerife-Los Rod...   Spain  A1  1977  27    03        MAR
#
#            day_of_week
# date
# 1977-03-27      Sunday
# 1977-03-27      Sunday

# %%
nb_victimes = df_accident_new['fatalities'].sum()
nb_victimes
# Out:
# 132701

# %%
nb_victimes_pays = df_accident_new.groupby('country')['fatalities'].sum().sort_values(ascending=False)
nb_victimes_pays
# Out:
# country
# USA              19305
# Russia            9968
# Brazil            3523
# India             3505
# France            3426
#                  ...
# Mauritius            0
# Macau                0
# Eswatini             0
# Seychelles           0
# French Guiana        0
# Name: fatalities, Length: 232, dtype: int32

# %%
nb_victimes_lieu = df_accident_new.groupby(['country', 'location'])['fatalities'].sum().sort_values(ascending=False)
nb_victimes_lieu
# Out:
# country      location
# USA          New York, NY                2747
# Spain        Tenerife-Los Rod...          772
# Japan        near Ueno Village, Ta...     520
# Libya        near Tripoli Internat...     368
# Kazakhstan   near Alma-Ata Airport...     349
#                                          ...
# Germany      Crailsheim-Advan...            0
# Russia       near Omsk                      0
#              near Omolon, Bilibino...       0
# Germany      Dessau Airport                 0
# Netherlands  Den Hout                       0
# Name: fatalities, Length: 14732, dtype: int32

# %% [markdown]
# # 11- Date with the highest number of casualties ? (directly affected or not)

# %%
date = df_accident_new.groupby(df_accident_new.index)['fatalities'].sum().sort_values(ascending=False)
date
# Out:
# date
# 2001-09-11    2890
# 1977-03-27     583
# 1985-08-12     522
# 1996-11-12     349
# 1974-03-03     347
#               ...
# 1989-06-06       0
# 1989-05-31       0
# 1989-05-27       0
# 1955-09-09       0
# 1977-04-20       0
# Name: fatalities, Length: 14911, dtype: int32

# %% [markdown]
# # Visualization

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df2 = df_accident_new.filter(items = ["date", "type", "operator", "fatalities", "location", "country"])

# %%
# Dates and number of casualties
date = df_accident_new.groupby(df_accident_new.index)['fatalities'].sum().sort_values(ascending=False)
date.head(30).plot(kind = 'line', title='Dates and number of casualties', xlabel='Year', ylabel='Number of casualties', figsize=(10,5))
# Out:
# <Axes: title={'center': 'Dates and number of casualties'}, xlabel='Year', ylabel='Number of casualties'>

# %%
# Countries and number of casualties
nb_victimes_pays = df_accident_new.groupby('country')['fatalities'].sum().sort_values(ascending=False)
nb_victimes_pays.head(10).plot(kind = 'bar', title='Country and number of casualties', xlabel='Countries', ylabel='Number of casualties', figsize=(10,5))
# Out:
# <Axes: title={'center': 'Country and number of casualties'}, xlabel='Countries', ylabel='Number of casualties'>

# %%
# Countries and number of incidents
nb_location = df_accident_new['country'].value_counts().sort_values(ascending=False)
nb_location.head(10).plot(kind='bar', xlabel='Countries', ylabel='Number of incidents', figsize=(10,5))
# Out:
# <Axes: xlabel='Countries', ylabel='Number of incidents'>

# %%
# weekday with the highest number of incidents
nb_day = df_accident_new['day_of_week'].value_counts().sort_values(ascending=True)
nb_day.plot(kind='barh', xlabel='Number of incidents', ylabel='Weekday', figsize=(8,5))
# Out:
# <Axes: xlabel='Number of incidents', ylabel='Weekday'>

# %%
# number of incident per month per country
df3 = pd.DataFrame(df_accident_new.groupby('country')['month_name'].value_counts())
df3 = df3.rename(columns={'month_name':'nb_incidents'})
df3
# Out:
#                      nb_incidents
# country  month_name
# ?        OCT                    4
#          AUG                    2
#          JUL                    2
#          NOV                    2
#          FEB                    1
# ...                           ...
# Zimbabwe JUL                    2
#          NOV                    2
#          SEP                    2
#          APR                    1
#          OCT                    1
#
# [2024 rows x 1 columns]

# %%
# number of casualties per month per country
df4 = pd.DataFrame(df_accident_new.groupby(['country', 'month_name'])['fatalities'].sum())
df4
# Out:
#                      fatalities
# country  month_name
# ?        AUG                  0
#          FEB                  4
#          JUL                  0
#          JUN                  0
#          MAR                  0
# ...                         ...
# Zimbabwe JUL                  1
#          MAR                  6
#          NOV                  2
#          OCT                  2
#          SEP                 38
#
# [2024 rows x 1 columns]

# %%
# merge df3 and df3 to have one dataframe with the number of incidents and casualties per month and per country
df5 = df3.merge(df4, on=['country', 'month_name'], how = 'inner')
df5
# Out:
#                      nb_incidents  fatalities
# country  month_name
# ?        OCT                    4           0
#          AUG                    2           0
#          JUL                    2           0
#          NOV                    2           0
#          FEB                    1           4
# ...                           ...         ...
# Zimbabwe JUL                    2           1
#          NOV                    2           2
#          SEP                    2          38
#          APR                    1           0
#          OCT                    1           2
#
# [2024 rows x 2 columns]

# %% [markdown]
# # USA, UK, France, Germany
# # For each country and month, find the number of incidents and casualties

# %%
fr = df5.filter(like="France", axis=0).sort_values(by='fatalities', ascending=False)
fr.plot(kind='bar', xlabel='Country, Month', ylabel='Number incidents, fatalities', figsize=(8,5))
# Out:
# <Axes: xlabel='Country, Month', ylabel='Number incidents, fatalities'>

# %%
ru = df5.filter(like="Russia", axis=0).sort_values(by='fatalities', ascending=False)
ru.plot(kind='bar', xlabel='Country, Month', ylabel='Number incidents, fatalities', figsize=(8,5))
# Out:
# <Axes: xlabel='Country, Month', ylabel='Number incidents, fatalities'>

# %%
usa = df5.filter(like="USA", axis=0).sort_values(by='fatalities', ascending=False)
usa.plot(kind='bar', xlabel='Country, Month', ylabel='Number incidents, fatalities', figsize=(8,5))
# Out:
# <Axes: xlabel='Country, Month', ylabel='Number incidents, fatalities'>

# %%
germ = df5.filter(like="Germany", axis=0).sort_values(by='fatalities', ascending=False)
germ.plot(kind='bar', xlabel='Country, Month', ylabel='Number incidents, fatalities', figsize=(8,5))
# Out:
# <Axes: xlabel='Country, Month', ylabel='Number incidents, fatalities'>

# %%
# export the dataframe to a csv file 

df_accident_new.to_csv("D:/Florian/Data Science/Data Analyst/Database Exemples/Aviation/accident_aviation_clean.csv")
